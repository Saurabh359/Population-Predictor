# %%
import pandas as pd
import numpy as np

# %%
#path to population csv file
df=pd.read_csv(r'C:\Users\user\Desktop\population.csv')

# %% [markdown]
# # Data Analysis

# %%
df.head()
# Out:
#       Country  Country Code     Indicator Name Indicator Code       1960  \
# 0        Aruba          ABW  Population, total    SP.POP.TOTL    54211.0
# 1  Afghanistan          AFG  Population, total    SP.POP.TOTL  8996973.0
# 2       Angola          AGO  Population, total    SP.POP.TOTL  5454933.0
# 3      Albania          ALB  Population, total    SP.POP.TOTL  1608800.0
# 4      Andorra          AND  Population, total    SP.POP.TOTL    13411.0
#
#         1961       1962       1963       1964       1965  ...        2010  \
# 0    55438.0    56225.0    56695.0    57032.0    57360.0  ...    101669.0
# 1  9169410.0  9351441.0  9543205.0  9744781.0  9956320.0  ...  29185507.0
# 2  5531472.0  5608539.0  5679458.0  5735044.0  5770570.0  ...  23356246.0
# 3  1659800.0  1711319.0  1762621.0  1814135.0  1864791.0  ...   2913021.0
# 4    14375.0    15370.0    16412.0    17469.0    18549.0  ...     84449.0
#
#          2011        2012        2013        2014        2015        2016  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 264 entries, 0 to 263
# Data columns (total 64 columns):
# Country           264 non-null object
# Country Code      264 non-null object
# Indicator Name    264 non-null object
# Indicator Code    264 non-null object
# 1960              260 non-null float64
# 1961              260 non-null float64
# 1962              260 non-null float64
# 1963              260 non-null float64
# 1964              260 non-null float64
# 1965              260 non-null float64
# 1966              260 non-null float64
# 1967              260 non-null float64
# 1968              260 non-null float64
# 1969              260 non-null float64
# 1970              260 non-null float64
# 1971              260 non-null float64
# 1972              260 non-null float64
# 1973              260 non-null float64
# 1974              260 non-null float64
# 1975              260 non-null float64
# 1976              260 non-null float64
# ...

# %%
df.isnull().sum()
# Out:
# 1960    0
# 1961    0
# 1962    0
# 1963    0
# 1964    0
# 1965    0
# 1966    0
# 1967    0
# 1968    0
# 1969    0
# 1970    0
# 1971    0
# 1972    0
# 1973    0
# 1974    0
# 1975    0
# 1976    0
# 1977    0
# 1978    0
# 1979    0
# 1980    0
# 1981    0
# 1982    0
# 1983    0
# 1984    0
# 1985    0
# 1986    0
# 1987    0
# 1988    0
# 1989    0
# 1990    0
# 1991    0
# 1992    1
# 1993    1
# 1994    1
# 1995    0
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    1
# 2013    1
# 2014    1
# 2015    1
# 2016    1
# 2017    1
# 2018    1
# dtype: int64

# %%
df.shape
# Out:
# (264, 64)

# %% [markdown]
# # Feature Engineering

# %%
df.drop(['2019'],axis=1,inplace=True)

# %%
years=list(map(str,range(1960,2019)))

# %%
df.set_index('Country ',inplace=True)

# %%
df.drop(['Country Code','Indicator Name','Indicator Code'],axis=1,inplace=True)

# %%
df
# Out:
#                                                             1960  \
# Country
# Aruba                                               5.421100e+04
# Afghanistan                                         8.996973e+06
# Angola                                              5.454933e+06
# Albania                                             1.608800e+06
# Andorra                                             1.341100e+04
# Arab World                                          9.219775e+07
# United Arab Emirates                                9.241800e+04
# Argentina                                           2.048178e+07
# Armenia                                             1.874121e+06
# American Samoa                                      2.012300e+04
# Antigua and Barbuda                                 5.413100e+04
# Australia                                           1.027648e+07
# Austria                                             7.047539e+06
# ...

# %%
df.dropna(subset=['1960'],axis=0,inplace=True)

# %% [markdown]
# # Data Visualization

# %%
import matplotlib as mp
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 1. Line Plots

# %%
def Line_charts(index):
    country_data=df.loc[index,years]
    country_data.plot(kind='line',figsize=(10,5))
    plt.title(index + " Population Distribution")
    plt.xlabel("Years")
    plt.ylabel("Population")
    plt.show()

# %%
Line_charts('Aruba')

# %%
Line_charts('Eritrea')

# %%
Line_charts('India')

# %%
Line_charts('Spain')

# %%
Line_charts('World')

# %% [markdown]
# ### 2. Bar Graph

# %% [markdown]
# ### # Population Comparison between different countries

# %%
def Bar_charts(feature,countries):
    temp=df.loc[countries,feature]
    temp.plot(kind='bar',figsize=(20,10))
    plt.title("Population Distribution in year "+ feature)
    plt.xlabel("Countries")
    plt.ylabel("Population")
    plt.show()

# %%
send=['Spain','China','India','United States','South Asia']
Bar_charts('2018',send)

# %% [markdown]
# ### # Population distribution between years in a country

# %%
def bar(country):
    df.loc[country,years].plot(kind='bar',figsize=(20,5))
    plt.title("Population Distribution of "+ country)
    plt.xlabel("Years")
    plt.ylabel("Popultion")
    plt.show()

# %%
bar('Aruba')

# %%
bar('India')

# %%
bar('China')

# %% [markdown]
# ## 3. Pie-chart

# %%
def pie_charts(feature,countries,ex,color):
    tea=df.loc[countries,feature]
    temp=pd.DataFrame({'Population':tea})
    total=temp.loc['World','Population']
    sum1=temp.sum(axis=0)
    var=sum1.loc['Population']
    var=var-total
    total1=total-var
    temp=temp.replace(to_replace=total,value=total1)
    total=temp.loc['World','Population']
    temp.rename(index={'World':'Others'},inplace=True)
    plt.pie(temp,labels=temp.index,radius=2,colors=color,startangle=-50,explode=ex,shadow=True,autopct='%0.1f%%')
    plt.show()

# %%
send1=['China','United States','India','World','Indonesia']
ex=[0,0,0.2,0,0]
color=['blue','green','red','yellow','purple']
pie_charts('2018',send1,ex,color)
# Out:
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:12: MatplotlibDeprecationWarning: Non-1D inputs to pie() are currently squeeze()d, but this behavior is deprecated since 3.1 and will be removed in 3.3; pass a 1D array instead.
#   if sys.path[0] == '':

# %% [markdown]
# # Model Devlopment

# %%
import seaborn as sns

# %%
def prediction_map(name):
    data = df.loc[name,years] 
    azx=pd.DataFrame(data)
    azx.reset_index(inplace=True)
    azx.rename(columns={'index':'Years',name:'Population'},inplace=True)
    azx['Years']=azx['Years'].astype('int')
    azx['Population']=azx['Population'].astype('int')
    sns.regplot(x='Years',y='Population',data=azx)
    plt.ylim(0,)

# %%
prediction_map('Aruba')

# %%
prediction_map('Australia')

# %%
prediction_map('India')

# %% [markdown]
# ### 1. Linear Regression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
lr=LinearRegression()

# %%
years1=list(map(str,range(1960,2011)))

# %%
original=[]
yer1=list(map(str,range(2011,2019)))
u=df.loc['India',yer1]
for d in u:
    original.append(d)

# %%
original
# Out:
# [1250288729.0,
#  1265782790.0,
#  1280846129.0,
#  1295604184.0,
#  1310152403.0,
#  1324509589.0,
#  1338658835.0,
#  1352617328.0]

# %%
def predict(name,yr):
    data = df.loc[name,years1] 
    out=pd.DataFrame(data)
    out.reset_index(inplace=True)
    out.rename(columns={'index':'Years',name:'Population'},inplace=True)
    out['Years']=out['Years'].astype('int')
    out['Population']=out['Population'].astype('int')
    x=out[['Years']]
    y=out['Population']
    lr.fit(x,y)
    gh=lr.predict([[yr]])
    #a=str(gh[0])
    #we=a.split('e')
    return gh[0]

# %%
y_predict=[]
for j in range(2011,2019):
    y_pr=predict('India',j)
    y_predict.append(y_pr)

# %%
y_predict
# Out:
# [1227970112.79451,
#  1244241719.468357,
#  1260513326.1422043,
#  1276784932.8160477,
#  1293056539.4898949,
#  1309328146.163742,
#  1325599752.8375893,
#  1341871359.5114326]

# %%
linear=mean_squared_error(original,y_predict)
print(linear)
# Out:
# 317310707198055.75

# %% [markdown]
# ### 2. Polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
data = df.loc['India',years] 
aout=pd.DataFrame(data)
aout.reset_index(inplace=True)
aout.rename(columns={'index':'Years','India':'Population'},inplace=True)
aout['Years']=aout['Years'].astype('int')
aout['Population']=aout['Population'].astype('int')
x=aout['Years']
y=aout['Population']

# %%
# degree=2
f=np.polyfit(x,y,2)
p=np.poly1d(f)
print(p)

# degree=9
f2=np.polyfit(x,y,9)
p2=np.poly1d(f2)
print(p2)
# Out:
#            2
# 5.827e+04 x - 2.153e+08 x + 1.986e+11
#             9             8             7            6         5
# -5.523e-13 x + 4.027e-09 x - 7.274e-06 x - 0.008725 x + 23.04 x
#               4             3             2
#  + 4.608e+04 x - 6.852e+07 x - 2.278e+11 x + 4.98e+14 x - 2.701e+17
# c:\users\user\appdata\local\programs\python\python37\lib\site-packages\ipykernel_launcher.py:7: RankWarning: Polyfit may be poorly conditioned
#   import sys

# %%
def PlotPolly(model, independent_variable, dependent_variabble, Name):
    x_new = np.linspace(1960,2018, 100)
    y_new = model(x_new)

    plt.plot(independent_variable, dependent_variabble, '.', x_new, y_new, '-')
    plt.title('Polynomial Fit with Matplotlib for Population ~ years')
    ax = plt.gca()
    ax.set_facecolor((0.898, 0.898, 0.898))
    fig = plt.gcf()
    plt.xlabel(Name)
    plt.ylabel('Population')

    plt.show()
    plt.close()

# %%
PlotPolly(p, aout['Years'], aout['Population'], 'years')  
PlotPolly(p2, aout['Years'], aout['Population'], 'years')

# %%
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.pipeline import Pipeline

# %%
def polyd(country,ye,i):
    pr=PolynomialFeatures(degree=i)
    data = df.loc[country,years1] 
    about=pd.DataFrame(data)
    about.reset_index(inplace=True)
    about.rename(columns={'index':'Years',country:'Population'},inplace=True)
    about['Years']=about['Years'].astype('int')
    about['Population']=about['Population'].astype('int')
    x=about['Years']
    y=about['Population']
    
    x_train=pr.fit_transform(about[['Years']])
    lr.fit(x_train,y)
    
    x_test=pr.fit_transform([[ye]])
    gh=lr.predict(x_test)
    #a=str(gh[0])
    #we=a.split('e')
    return gh[0]

# %%
y_pre=[]
for j in range(2011,2019):
    y_pr=polyd('India',j,23)
    y_pre.append(y_pr)
y_pre
# Out:
# [1249559181.1031227,
#  1265268457.2627907,
#  1280545351.0499,
#  1295355462.8545876,
#  1309663516.9346657,
#  1323433345.8394508,
#  1336627874.600193,
#  1349209104.7115211]

# %%
polynom=mean_squared_error(original,y_pre)
print(polynom)
# Out:
# 2260900367133.1934

# %%
if polynom>linear:
    print("Linear is good")
else :
    print("Polynomial is good")
# Out:
# Polynomial is good

# %% [markdown]
# ## Polynomial Predicts better

# %% [markdown]
# ### Final Model Creation

# %%
def poly_predict(country,ye,i):
    pr=PolynomialFeatures(degree=i)
    data = df.loc[country,years] 
    about=pd.DataFrame(data)
    about.reset_index(inplace=True)
    about.rename(columns={'index':'Years',country:'Population'},inplace=True)
    about['Years']=about['Years'].astype('int')
    about['Population']=about['Population'].astype('int')
    x=about['Years']
    y=about['Population']
    
    x_train=pr.fit_transform(about[['Years']])
    lr.fit(x_train,y)
    
    x_test=pr.fit_transform([[ye]])
    gh=lr.predict(x_test)
    return gh[0]

# %%
def checking(country):
    original_1=[]
    u=df.loc[country,yer1]
    for d in u:
        original_1.append(d)
    prev=0
    current=0
    for i in range(2,50):
        y_pred=[]
        for j in range(2011,2019):
            y_pr=polyd(country,j,i)
            y_pred.append(y_pr)
        polynom=mean_squared_error(original_1,y_pred)
        current=polynom
        if (current>prev) & (i!=2):
            return i
        else :
            prev=current

# %%
def predict_population(country,year):  
    best_fit=checking(country)
    print(best_fit)
    return poly_predict(country,year,best_fit)

# %%
input1='India'
year_input=2019
result=predict_population(input1,year_input)
print("Population of "+ input1 +" in year "+ str(year_input) +" is : "+  str(round(result, 2)) +" approx")
Line_charts(input1)
# Out:
# 21
# Population of India in year 2019 is : 1363671002.94 approx
